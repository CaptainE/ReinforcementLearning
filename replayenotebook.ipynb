# %% [markdown]
# # Note that generates replay

# %%
from agent import *
from REINFORCE import *
from DQN import *
# Out:
# CUDA has been enabled.

# %% [markdown]
# # Load agent based on the name #

# %%
agent = load_agent("REINFORCE_num_episodes=20000_discount_factor=0.99_lr=0.0003_test_freq=50")

# %%
agent.get_replay()

# %% [markdown]
# # Load stats

# %%
import pickle
with open('agents/REINFORCE_num_episodes=20000_discount_factor=0.99_lr=0.0003_test_freq=50.stats', 'rb') as f:
    stats = pickle.load(f)
rollouts, rewards = stats

# %%
import numpy as np

episode = np.arange(0,20000,step=50)

r = np.array(rewards)
r_mean = r.mean(axis=1)
r_std = r.std(axis=1)

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

plt.plot(episode, r_mean)
